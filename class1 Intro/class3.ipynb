# %% [markdown]
# # OPERATORS
#
# - Addition +
# - Subtraction -
# - Multiplication *
# - Division/
# - Power **

# %%
#NOW APPLYING THESE OPERTORS 

2 + 5
# Out:
# 7

# %%
2 - 5
# Out:
# -3

# %%
2 * 7
# Out:
# 14

# %%
7 / 2 # / complete answer
# Out:
# 3.5

# %%
7 ** 2
# Out:
# 49

# %% [markdown]
# # UNFAMILIAR OPERATORS
#
# - Remainder /
# - Modulus %
# - floor //

# %%
20 / 5
# Out:
# 4.0

# %%
20 / 3
# Out:
# 6.666666666666667

# %%
20 % 3 # after division jo values remainder reh jati hain un ka pata lagany k liye % use krty hain
# Out:
# 2

# %%
13 % 4
# Out:
# 1

# %%
13 // 4 # division k bad agr ans point me ay tw yrh // un point k bad wali values ko remove kr ddeta hai
# Out:
# 3

# %%
26 // 5
# Out:
# 5

# %% [markdown]
# # EXPRESSION (BODMASS)
# - now we learn about 'EXPRESSION' (bodmass)

# %%
((5 + 4) + (4 - 2)) - 5
# (9 + 2) - 5
# 11 -5
# 6--> answer
# Out:
# 6

# %%
((5 * 4) + (4 - 2)) - 5 
# (20 + 2) -5
# 22 - 5 
# 17--> answer
# Out:
# 17

# %%
((((4 * 2) + 2 ) / 5 )*3) + 1
# (((8 + 2) /5) * 3) + 1
# ((10 / 5) * 3) + 1
# (2 * 3) + 1
# 6 + 1
# 7--> answer
# Out:
# 7.0
